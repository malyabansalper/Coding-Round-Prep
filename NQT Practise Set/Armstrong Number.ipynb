# %%
# to check a number is armstrong or not
#link for problem ---> https://practice.geeksforgeeks.org/problems/armstrong-numbers2727/1#


n=int(input("Enter number : "))
# Out:
# Enter number : 153

# %%
def countDigits(n):
    digits=0
    while(n!=0):
        digits+=1
        n=n//10
    return digits

# %%
def isArmstrong(n):
    digi=countDigits(n)
    s=0
    x=n
    while(x!=0):
        r=x%10
        s=s+(r**digi)
        x=x//10
    if(s==n):
        return (print("Yes"))
    else:
        return (print("No"))

# %%
isArmstrong(n)
# Out:
# Yes

# %%
isArmstrong(121)
# Out:
# No

# %%
isArmstrong(577)
# Out:
# No
